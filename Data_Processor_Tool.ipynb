# %%
import requests
import pandas as pd
import time
import sqlite3

def fetch_data(url, params):
    data_list = []
    while True:
        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()
            for item in data['items']:
                # use 'resourceBaseUri' from data
                item['FullURL'] = data['resourceBaseUri'] + '/' + item['ResourceName']
                data_list.append(item)
            print(f"Current page: {params['page']}, Total pages: {data['pagination']['totalPages']}, Total items fetched: {len(data_list)}")
            if params["page"] >= data['pagination']['totalPages']:
                break
            params["page"] += 1
            time.sleep(1)
        else:
            print(f"Request failed with status code {response.status_code}")
            break
    df = pd.DataFrame(data_list)
    df.drop_duplicates(subset='_id', keep='first', inplace=True)  # Drop duplicate rows based on the '_id' column
    return df


url1 = "https://reports.semopx.com/api/v1/documents/static-reports/"
url2 = "https://reports.sem-o.com/api/v1/documents/static-reports/"

params1 = {
    "page": 1,
    "sort_by": "PublishTime",
    "order_by": "DESC",
    "name": "",
    "DPuG_ID": "",
    "group[]": ["Market Data"],
    "date_from": "",
    "date_to": "",
    "page_size": 120
}

params2 = {
    "page": 1,
    "sort_by": "PublishTime",
    "order_by": "DESC",
    "name": "",
    "DPuG_ID": "",
    "group[]": [
        "Capacity Qualification", 
        "Capacity Auctions", 
        "Forecast Data", 
        "Inputs, Commerical and Technical Offer Data", 
        "Registration", 
        "Settlement Data"
    ],
    "date_from": "",
    "date_to": "",
    "page_size": 120
}

# ea

SEMOPX_DPuG_IDs = ["EA-004"]
SEMO_DPuG_IDs = ["BM-010", "BM-013"]

dataframes_dict = {}

for DPuG_ID in SEMOPX_DPuG_IDs:
    params1["DPuG_ID"] = DPuG_ID
    params1["page"] = 1  # reset page to 1 for new ID
    dataframes_dict[DPuG_ID] = fetch_data(url1, params1)

for DPuG_ID in SEMO_DPuG_IDs:
    params2["DPuG_ID"] = DPuG_ID
    params2["page"] = 1  # reset page to 1 for new ID
    dataframes_dict[DPuG_ID] = fetch_data(url2, params2)

for df_key in dataframes_dict.keys():
    if 'Group' in dataframes_dict[df_key].columns:
        dataframes_dict[df_key]['Group'] = dataframes_dict[df_key]['Group'].apply(', '.join)
    else:
        print(f"Dataframe {df_key} does not contain 'Group' column")

# Create a connection for the SQLite database
conn = sqlite3.connect('SEMOPX.db')

# Create a cursor object using the cursor() method
cursor = conn.cursor()

# Iterate over all dataframes in the dictionary
for df_key in dataframes_dict.keys():
    # Replace hyphen in the dataframe key with underscore for table name
    table_name = df_key.replace('-', '_')
    
    # Replace problematic characters in the column names
    dataframes_dict[df_key].columns = dataframes_dict[df_key].columns.str.replace("[()]", "")
    
    # Check if table exists, create a new table if it doesn't
    cursor.execute(f"SELECT name FROM sqlite_master WHERE type='table' AND name='{table_name}';")
    table_exists = cursor.fetchone()
    
    if table_exists:
        # Load the existing data
        df_existing = pd.read_sql_query(f'SELECT * FROM {table_name}', conn)
        
        # Find new rows
        df_new = pd.concat([dataframes_dict[df_key], df_existing])
        df_new.drop_duplicates(subset='_id', keep='first', inplace=True)
        
        # Append new rows
        df_new.to_sql(table_name, conn, if_exists='replace', index=False)
        
    # If table does not exist, write the DataFrame
    else:
        dataframes_dict[df_key].to_sql(table_name, conn, if_exists='replace', index=False)

# close the connection
conn.close()
# Out:
# Current page: 1, Total pages: 13, Total items fetched: 120
# Current page: 2, Total pages: 13, Total items fetched: 240
# Current page: 3, Total pages: 13, Total items fetched: 360
# Current page: 4, Total pages: 13, Total items fetched: 480
# Current page: 5, Total pages: 13, Total items fetched: 600
# Current page: 6, Total pages: 13, Total items fetched: 720
# Current page: 7, Total pages: 13, Total items fetched: 840
# Current page: 8, Total pages: 13, Total items fetched: 960
# Current page: 9, Total pages: 13, Total items fetched: 1080
# Current page: 10, Total pages: 13, Total items fetched: 1200
# Current page: 11, Total pages: 13, Total items fetched: 1320
# Current page: 12, Total pages: 13, Total items fetched: 1440
# Current page: 13, Total pages: 13, Total items fetched: 1460
# Current page: 1, Total pages: 96, Total items fetched: 120
# Current page: 2, Total pages: 96, Total items fetched: 240
# Current page: 3, Total pages: 96, Total items fetched: 360
# Current page: 4, Total pages: 96, Total items fetched: 480
# Current page: 5, Total pages: 96, Total items fetched: 600
# Current page: 6, Total pages: 96, Total items fetched: 720
# Current page: 7, Total pages: 96, Total items fetched: 840
# Current page: 8, Total pages: 96, Total items fetched: 960
# Current page: 9, Total pages: 96, Total items fetched: 1080
# Current page: 10, Total pages: 96, Total items fetched: 1200
# Current page: 11, Total pages: 96, Total items fetched: 1320
# Current page: 12, Total pages: 96, Total items fetched: 1440
# Current page: 13, Total pages: 96, Total items fetched: 1560
# Current page: 14, Total pages: 96, Total items fetched: 1680
# Current page: 15, Total pages: 96, Total items fetched: 1800
# Current page: 16, Total pages: 96, Total items fetched: 1920
# Current page: 17, Total pages: 96, Total items fetched: 2040
# Current page: 18, Total pages: 96, Total items fetched: 2160
# Current page: 19, Total pages: 96, Total items fetched: 2280
# Current page: 20, Total pages: 96, Total items fetched: 2400
# Current page: 21, Total pages: 96, Total items fetched: 2520
# Current page: 22, Total pages: 96, Total items fetched: 2640
# Current page: 23, Total pages: 96, Total items fetched: 2760
# Current page: 24, Total pages: 96, Total items fetched: 2880
# Current page: 25, Total pages: 96, Total items fetched: 3000
# Current page: 26, Total pages: 96, Total items fetched: 3120
# Current page: 27, Total pages: 96, Total items fetched: 3240
# Current page: 28, Total pages: 96, Total items fetched: 3360
# Current page: 29, Total pages: 96, Total items fetched: 3480
# Current page: 30, Total pages: 96, Total items fetched: 3600
# Current page: 31, Total pages: 96, Total items fetched: 3720
# Current page: 32, Total pages: 96, Total items fetched: 3840
# Current page: 33, Total pages: 96, Total items fetched: 3960
# Current page: 34, Total pages: 96, Total items fetched: 4080
# Current page: 35, Total pages: 96, Total items fetched: 4200
# Current page: 36, Total pages: 96, Total items fetched: 4320
# Current page: 37, Total pages: 96, Total items fetched: 4440
# Current page: 38, Total pages: 96, Total items fetched: 4560
# Current page: 39, Total pages: 96, Total items fetched: 4680
# Current page: 40, Total pages: 96, Total items fetched: 4800
# Current page: 41, Total pages: 96, Total items fetched: 4920
# Current page: 42, Total pages: 96, Total items fetched: 5040
# Current page: 43, Total pages: 96, Total items fetched: 5160
# Current page: 44, Total pages: 96, Total items fetched: 5280
# Current page: 45, Total pages: 96, Total items fetched: 5400
# Current page: 46, Total pages: 96, Total items fetched: 5520
# Current page: 47, Total pages: 96, Total items fetched: 5640
# Current page: 48, Total pages: 96, Total items fetched: 5760
# Current page: 49, Total pages: 96, Total items fetched: 5880
# Current page: 50, Total pages: 96, Total items fetched: 6000
# Current page: 51, Total pages: 96, Total items fetched: 6120
# Current page: 52, Total pages: 96, Total items fetched: 6240
# Current page: 53, Total pages: 96, Total items fetched: 6360
# Current page: 54, Total pages: 96, Total items fetched: 6480
# Current page: 55, Total pages: 96, Total items fetched: 6600
# Current page: 56, Total pages: 96, Total items fetched: 6720
# Current page: 57, Total pages: 96, Total items fetched: 6840
# Current page: 58, Total pages: 96, Total items fetched: 6960
# Current page: 59, Total pages: 96, Total items fetched: 7080
# Current page: 60, Total pages: 96, Total items fetched: 7200
# Current page: 61, Total pages: 96, Total items fetched: 7320
# Current page: 62, Total pages: 96, Total items fetched: 7440
# Current page: 63, Total pages: 96, Total items fetched: 7560
# Current page: 64, Total pages: 96, Total items fetched: 7680
# Current page: 65, Total pages: 96, Total items fetched: 7800
# Current page: 66, Total pages: 96, Total items fetched: 7920
# Current page: 67, Total pages: 96, Total items fetched: 8040
# Current page: 68, Total pages: 96, Total items fetched: 8160
# Current page: 69, Total pages: 96, Total items fetched: 8280
# Current page: 70, Total pages: 96, Total items fetched: 8400
# Current page: 71, Total pages: 96, Total items fetched: 8520
# Current page: 72, Total pages: 96, Total items fetched: 8640
# Current page: 73, Total pages: 96, Total items fetched: 8760
# Current page: 74, Total pages: 96, Total items fetched: 8880
# Current page: 75, Total pages: 96, Total items fetched: 9000
# Current page: 76, Total pages: 96, Total items fetched: 9120
# Current page: 77, Total pages: 96, Total items fetched: 9240
# Current page: 78, Total pages: 96, Total items fetched: 9360
# Current page: 79, Total pages: 96, Total items fetched: 9480
# Current page: 80, Total pages: 96, Total items fetched: 9600
# Current page: 81, Total pages: 96, Total items fetched: 9720
# Current page: 82, Total pages: 96, Total items fetched: 9840

# %%
conn = sqlite3.connect('SEMOPX.db')

# Read from the "EA_004" table into a DataFrame and create a list of 'FullURL'
bidaskcurves_df = pd.read_sql_query("SELECT * FROM EA_004", conn)
bidaskcurves_list = bidaskcurves_df['FullURL'].tolist()


# Read from the "BM_013" table into a DataFrame and create a list of 'FullURL'
FourDayWindUnitForecast_df = pd.read_sql_query("SELECT * FROM BM_013", conn)
FourDayWindUnitForecast_list  = FourDayWindUnitForecast_df['FullURL'].tolist()


# Read from the "BM_010" table into a DataFrame and create a list of 'FullURL'
DailyLoadForecast_df = pd.read_sql_query("SELECT * FROM BM_010", conn)
DailyLoadForecast_list  = DailyLoadForecast_df['FullURL'].tolist()



conn.close()

# %%
# Out:
# ['https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA3_20230604_20230604151633.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-DA_20230605_20230604131316.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA2_20230604_20230604093537.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA1_20230604_20230603190712.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA3_20230603_20230603151619.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-DA_20230604_20230603131200.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA2_20230603_20230603093525.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA1_20230603_20230602191446.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA3_20230602_20230602151632.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-DA_20230603_20230602131354.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA2_20230602_20230602093719.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA1_20230602_20230601190708.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA3_20230601_20230601151626.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-DA_20230602_20230601131302.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA2_20230601_20230601093533.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA1_20230601_20230531190707.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA3_20230531_20230531151629.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-DA_20230601_20230531131138.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA2_20230531_20230531093528.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA1_20230531_20230530190713.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA3_20230530_20230530151635.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-DA_20230531_20230530131219.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA2_20230530_20230530093542.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA1_20230530_20230529190703.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA3_20230529_20230529151620.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-DA_20230530_20230529131211.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA2_20230529_20230529093526.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA1_20230529_20230528190651.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA3_20230528_20230528151639.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-DA_20230529_20230528140717.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA2_20230528_20230528093537.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA1_20230528_20230527190701.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA3_20230527_20230527151623.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-DA_20230528_20230527144228.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA2_20230527_20230527093522.xml', 'https://reports.semopx.com/api/v1/documents/static-reports/BidAskCurves_SEM-IDA1_20230527_202305 ...
